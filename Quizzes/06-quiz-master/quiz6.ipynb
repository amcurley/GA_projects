# %%
def adj(onek):
    count = 1001
    string = str(onek)[::-1]
    
#   I need to check the 13 adjacent numbers if 0 is in there drop that
    first = 0
    second = first + 13
    
    good = ''
    while count != 0:
        if '0' in string[first: second]:
            print('dropped')
            first += second
            count -= 1
        else:
            good + string # I will need to get the final good list of the nunbers
            
    # I think I might have to do recrusion
    return good

# %%
adj(...)
# Out:
# dropped
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-104-a3b406fbca8a> in <module>
# ----> 1 adj([0;...)
#
# <ipython-input-103-1053716bbf6c> in adj(onek)
#       9     good = ''
#      10     while count != 0:
# ---> 11         if '0' in string[first: second]:
#      12             print('dropped')
#      13             first += second
#
# KeyboardInterrupt:
