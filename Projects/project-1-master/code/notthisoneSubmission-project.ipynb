# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# as well as an

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat_2017 = pd.read_csv('/Users/aidancurley/Documents/dsir/Submissions/Projects/project-1-master/data/sat_2017.csv')
act_2017 = pd.read_csv('/Users/aidancurley/Documents/dsir/Submissions/Projects/project-1-master/data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#    Composite
# 0       21.0
# 1       19.2
# 2       19.8
# 3       19.7
# 4       19.4
# 5       22.8
# 6       20.8
# 7       25.2
# 8       24.1
# 9       24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# **Answer:** First we will start with the sat_2017 dataset. This dataset contains 51 rows for all 50 states and the District of Columbia. There are 5 columns in this data set: 'State', 'Participation', Evidence-Based Reading and Writing', 'Math', and 'Total.' In sat_2017 there are no null values which means the dataset is complete. The average scores across all 50 states and the District of Columbia for Evidence-Based Reading and Writing is a score of 569. The average scores across all 50 states and the District of Columbia for Math is a score of 547. The average scores across all 50 states and the District of Columbia for the toal is a score of 1126.
#
# The act_2017 dataset contains 52 rows. This includes 50 rows for all 50 states, a row for the District of Columbia and a row for the nation as a whole. There are 7 columns in this dataset: 'State', 'Participation', 'English', 'Math', 'Reading', 'Science', 'Composite.'In act_2017 there are no null values which means the dataset is complete. However in the 'Composite' column Wyoming has a value of 20.2x which is not like the other values so this was most likely an error which occured in data entry. In the 'Science' column Maryland has a value of 2.3 which is not possible. The average score for English was 20.9, the average socre for Math was 21.1, the average score for reading ws 22.0, the average score for science was 21.0.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# **Answer:**
# No, the data is not complete. There are a few errors in both datasets.
#
#
# The sat_2017 dataset is not complete because the value for Maryland in the 'Math' column is 52 which is impossible. The act_2017 dataset is not complete because in the 'Composite' column Wyoming has a value of 20.2x which makes the 'Composite' column datatype an object instead of an integer. Also, the value for Maryland in the 'Science' column is 2.3 which is not possible.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# **Answer:**
#
# sat_2017
# * **ERROR** Accoring to https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/ the value for Maryland in the 'Math' column should be 524.
# * The minimum for Evidence-Base Reading and riding was 482. The minimum for the total was 950. The maximum for Math is 651.
# * The maximum for Evidence-Based Reading and Writing is 644. The maximum for total is 1295.
#
# act_2017
#
# * **ERROR** Accoring to https://www.act.org/content/dam/act/unsecured/documents/cccr2017/ACT_2017-Average_Scores_by_State.pdf the value for Maryland in the 'Science' column should be 23.3 not 2.3
# * **ERROR** In the 'Composite' column Wyoming has a value of 20.2x. It should just be 20.2
# * The minimum value in the 'Science' column is 2.3. The minimum for 'English' is 16.3. The minimum for 'Math' is 18.0. The minimum for 'Reading' is 18.1.
# * The maximum for 'English' is 25.5. The maximum for 'Math' is 25.3. The maximum for 'Reading' is 26. The maximum for 'Science' is 24.9.

# %%
sat_2017.head(1)
# Out:
#      State Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama            5%                                 593   572   1165

# %%
act_2017.head(1)
# Out:
#       State Participation  English  Math  Reading  Science  Composite
# 0  National           60%     20.3  20.7     21.4     21.0       21.0

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
# How to fix the errors I identified

# This fixes the error of Maryland in the column 'math_sat' Changes 52 to 524
sat_2017.at[20, 'Math'] = 524

# This fixes the error for Maryland in the column 'science_act' Changes 2.3 to 23.2
act_2017.at[21, 'Science']= 23.2

# This fixes the error for Wyoming in the column 'composite' Changes 20.2x to 20.2
act_2017.at[51, 'Composite']= 20.2

# %%
# We can see the updated values here for the sat_2017 dataset
sat_2017.loc[(sat_2017['State'] == 'Maryland')]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536   524   1060

# %%
# We can see the updated values here for the act_2017 dataset
act_2017.loc[(act_2017['State'] == 'Maryland')]
# Out:
#        State Participation  English  Math  Reading  Science  Composite
# 21  Maryland           28%     23.3  23.1     24.2     23.2       23.6

# %%
# We can see the updated values here for the act_2017 dataset
act_2017.loc[(act_2017['State'] == 'Wyoming')]
# Out:
#       State Participation  English  Math  Reading  Science  Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6       20.2

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
# Datatypes for sat_2017
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
# Datatypes for act_2017
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# **Answer:**
#
# The 'Participation' columns should be a float datatype so we can work with it later on. Also, in the act_2017 dataset the 'Composite' column datatype was an object before I updated the value. Now it is the proper datatype.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
sat_2017.head(2)
# Out:
#   2017_state 2017_sat_participation  evidence-based reading and writing  \
# 0    Alabama                     5%                                 593
# 1     Alaska                    38%                                 547
#
#    2017_sat_math  2017_sat_total
# 0            572            1165
# 1            533            1080

# %%
act_2017.head(2)
# Out:
#   2017_state 2017_act_participation  2017_act_english  2017_act_math  \
# 0   National                    60%              20.3           20.7
# 1    Alabama                   100%              18.9           18.4
#
#    2017_act_reading  2017_act_science  2017_act_composite
# 0              21.4              21.0                21.0
# 1              19.7              19.4                19.2

# %%
#code

# This code makes the values in 'Participation' turn into floats
sat_2017['2017_sat_participation'] = sat_2017['2017_sat_participation'].map(lambda x: float(x[:-1]))
act_2017['2017_act_participation'] = act_2017['2017_act_participation'].map(lambda x: float(x[:-1]))

# %%
# Now they are floats
act_2017.head(3)
# Out:
#   2017_state  2017_act_participation  2017_act_english  2017_act_math  \
# 0   National                    60.0              20.3           20.7
# 1    Alabama                   100.0              18.9           18.4
# 2     Alaska                    65.0              18.7           19.8
#
#    2017_act_reading  2017_act_science  2017_act_composite
# 0              21.4              21.0                21.0
# 1              19.7              19.4                19.2
# 2              20.4              19.9                19.8

# %%
# Now they are floats
sat_2017.head(3)
# Out:
#      State Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama            5%                                 593   572   1165
# 1   Alaska           38%                                 547   533   1080
# 2  Arizona           30%                                 563   553   1116

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# Fixed the individual values in 4c

# This is how I fixes the individual values

# # This fixes the error of Maryland in the column 'math_sat' Changes 52 to 524
# sat_2017.at[20, 'Math'] = 524

# # This fixes the error for Maryland in the column 'science_act' Changes 2.3 to 23.2
# act_2017.at[21, 'Science']= 23.2

# # This fixes the error for Wyoming in the column 'composite' Changes 20.2x to 20.2
# act_2017.at[51, 'Composite']= 20.2

# %%
act_2017.tail()
# Out:
#        2017_state  2017_act_participation  2017_act_english  2017_act_math  \
# 47       Virginia                    29.0              23.5           23.3
# 48     Washington                    29.0              20.9           21.9
# 49  West Virginia                    69.0              20.0           19.4
# 50      Wisconsin                   100.0              19.7           20.4
# 51        Wyoming                   100.0              19.4           19.8
#
#     2017_act_reading  2017_act_science  2017_act_composite
# 47              24.6              23.5                23.8
# 48              22.1              22.0                21.9
# 49              21.2              20.5                20.4
# 50              20.6              20.9                20.5
# 51              20.8              20.6                20.2

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code: 
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
sat_2017.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
act_2017.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %%
# Making the columns lowercase
sat_2017.columns = sat_2017.columns.str.lower()
sat_2017.columns
# Out:
# Index(['state', 'participation', 'evidence-based reading and writing', 'math',
#        'total'],
#       dtype='object')

# %%
# Making the columns lowercase
act_2017.columns = act_2017.columns.str.lower()
act_2017.columns
# Out:
# Index(['state', 'participation', 'english', 'math', 'reading', 'science',
#        'composite'],
#       dtype='object')

# %%
# Renaming the sat_2017 columns
sat_2017.rename(columns={'state': 'sat_state',
                         'participation': 'sat_participation',
                         'math': 'sat_math',
                         'total': 'sat_total'
                    }, inplace=True)

# %%
sat_2017.head(2)
# Out:
#   sat_state sat_participation  evidence-based reading and writing  sat_math  \
# 0   Alabama                5%                                 593       572
# 1    Alaska               38%                                 547       533
#
#    sat_total
# 0       1165
# 1       1080

# %%
# Renaming the act_2017 columns
act_2017.rename(columns={'state': 'act_state',
                         'participation': 'act_participation',
                         'english': 'act_english',
                         'math': 'act_math',
                         'reading': 'act_reading',
                         'science': 'act_science',
                         'composite': 'act_composite'
                    }, inplace=True)

# %%
act_2017.head(2)
# Out:
#   act_state act_participation  act_english  act_math  act_reading  \
# 0  National               60%         20.3      20.7         21.4
# 1   Alabama              100%         18.9      18.4         19.7
#
#    act_science  act_composite
# 0         21.0           21.0
# 1         19.4           19.2

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|object|sat_2017|All 50 states and the District of Columbia|
# |**2017_sat_participation**|float|sat_2017|The overall percentage of people taking the SAT in that state in 2017|
# |**2017_sat_evidence_based_reading_and_writing**|int|sat_2017|The average score for the evidence-based reading and writing section of the SAT for each state |
# |**2017_sat_math**|int|sat_2017|The average score for the math section of the SAT for each state|
# |**2017_sat_total**|int|sat_2017|The overall average total score of the SAT for each state |
# |**state**|object|act_2017|All 50 states, the District of Columbia, and the national average for each section|
# |**2017_participation**|float|act_2017|The overall percentage of people taking the ACT in that state in 2017|
# |**2017_act_english**|float|act_2017|The average score for the english section of the ACT for each state and the national average|
# |**2017_act_math**|float|act_2017|The average score for the math section of the ACT for each state and the national average|
# |**2017_act_reading**|float|act_2017|The average score for the reading section of the ACT for each state and the national average |
# |**2017_act_science**|float|act_2017|The average score for the science section of the ACT for each state and the national average |
# |**2017_act_composite**|float|act_2017|The average score on the ACT for each state and the national average score|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
act_2017.head()
# Out:
#   act_state act_participation  act_english  act_math  act_reading  \
# 0  National               60%         20.3      20.7         21.4
# 1   Alabama              100%         18.9      18.4         19.7
# 2    Alaska               65%         18.7      19.8         20.4
# 3   Arizona               62%         18.6      19.8         20.1
# 4  Arkansas              100%         18.9      19.0         19.7
#
#    act_science  act_composite
# 0         21.0           21.0
# 1         19.4           19.2
# 2         19.9           19.8
# 3         19.8           19.7
# 4         19.5           19.4

# %%
#code
# act_2017 contains an extra row

# This is the code to drop the extra row
# act_2017.drop([act_2017.index[0]], inplace=True)

# %%
act_2017.shape
# Out:
# (52, 7)

# %%
sat_2017.head(3)
# Out:
#   sat_state sat_participation  evidence-based reading and writing  sat_math  \
# 0   Alabama                5%                                 593       572
# 1    Alaska               38%                                 547       533
# 2   Arizona               30%                                 563       553
#
#    sat_total
# 0       1165
# 1       1080
# 2       1116

# %%
act_2017.rename(columns={'act_state': '2017_state'}, inplace=True)

# %%
sat_2017.rename(columns={'sat_state': '2017_state'}, inplace=True)

# %%
sat_2017.head(3)
# Out:
#   2017_state sat_participation  evidence-based reading and writing  sat_math  \
# 0    Alabama                5%                                 593       572
# 1     Alaska               38%                                 547       533
# 2    Arizona               30%                                 563       553
#
#    sat_total
# 0       1165
# 1       1080
# 2       1116

# %%
act_2017.head(3)
# Out:
#   2017_state act_participation  act_english  act_math  act_reading  \
# 0   National               60%         20.3      20.7         21.4
# 1    Alabama              100%         18.9      18.4         19.7
# 2     Alaska               65%         18.7      19.8         20.4
#
#    act_science  act_composite
# 0         21.0           21.0
# 1         19.4           19.2
# 2         19.9           19.8

# %%
act_2017.columns
# Out:
# Index(['2017_state', 'act_participation', 'act_english', 'act_math',
#        'act_reading', 'act_science', 'act_composite'],
#       dtype='object')

# %%
act_2017.rename(columns={'act_participation': '2017_act_participation',
                         'act_english': '2017_act_english',
                         'act_math': '2017_act_math',
                         'act_reading': '2017_act_reading',
                         'act_science': '2017_act_science',
                         'act_composite': '2017_act_composite'}, inplace=True)

# %%
sat_2017.columns
# Out:
# Index(['2017_state', 'sat_participation', 'evidence-based reading and writing',
#        'sat_math', 'sat_total'],
#       dtype='object')

# %%
sat_2017.rename(columns={'sat_participation': '2017_sat_participation',
                         'sat_evidence_based_reading_and_writing': '2017_sat_evidence_based_reading_and_writing',
                         'sat_math': '2017_sat_math',
                         'sat_total': '2017_sat_total'}, inplace=True)

# %%
sat_2017.rename(columns={'evidence-based reading and writing': '2017_sat_evidence_based_reading_and_writing'
                        }, inplace=True)

# %%
sat_2017.head(1)
# Out:
#   2017_state  2017_sat_participation  \
# 0    Alabama                     5.0
#
#    2017_sat_evidence_based_reading_and_writing  2017_sat_math  2017_sat_total
# 0                                          593            572            1165

# %%
act_2017.head(1)
# Out:
#   2017_state  2017_act_participation  2017_act_english  2017_act_math  \
# 0   National                    60.0              20.3           20.7
#
#    2017_act_reading  2017_act_science  2017_act_composite
# 0              21.4              21.0                21.0

# %%
sat_2017.rename(columns={'2017_state': 'state'
                        }, inplace=True)

# %%
sat_2017.head(1)
# Out:
#      state  2017_sat_participation  \
# 0  Alabama                     5.0
#
#    2017_sat_evidence_based_reading_and_writing  2017_sat_math  2017_sat_total
# 0                                          593            572            1165

# %%
act_2017.rename(columns={'2017_state': 'state'
                        }, inplace=True)

# %%
act_2017.head()
# Out:
#       state  2017_act_participation  2017_act_english  2017_act_math  \
# 0  National                    60.0              20.3           20.7
# 1   Alabama                   100.0              18.9           18.4
# 2    Alaska                    65.0              18.7           19.8
# 3   Arizona                    62.0              18.6           19.8
# 4  Arkansas                   100.0              18.9           19.0
#
#    2017_act_reading  2017_act_science  2017_act_composite
# 0              21.4              21.0                21.0
# 1              19.7              19.4                19.2
# 2              20.4              19.9                19.8
# 3              20.1              19.8                19.7
# 4              19.7              19.5                19.4

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code: 
# This code will merge the dataframe
#pd.merge(pd.merge(openprice,stockname,on='Symbol')
combined_2017 = pd.merge(sat_2017, act_2017, on='state')
combined_2017.head()
# Out:
#         state  2017_sat_participation  \
# 0     Alabama                     5.0
# 1      Alaska                    38.0
# 2     Arizona                    30.0
# 3    Arkansas                     3.0
# 4  California                    53.0
#
#    2017_sat_evidence_based_reading_and_writing  2017_sat_math  2017_sat_total  \
# 0                                          593            572            1165
# 1                                          547            533            1080
# 2                                          563            553            1116
# 3                                          614            594            1208
# 4                                          531            524            1055
#
#    2017_act_participation  2017_act_english  2017_act_math  2017_act_reading  \
# 0                   100.0              18.9           18.4              19.7
# 1                    65.0              18.7           19.8              20.4
# ...

# %%
combined_2017.rename(columns={'2017_state': 'state'}, inplace=True)

# %%
combined_2017.head()
# Out:
#         state  2017_sat_participation  \
# 0     Alabama                     5.0
# 1      Alaska                    38.0
# 2     Arizona                    30.0
# 3    Arkansas                     3.0
# 4  California                    53.0
#
#    2017_sat_evidence_based_reading_and_writing  2017_sat_math  2017_sat_total  \
# 0                                          593            572            1165
# 1                                          547            533            1080
# 2                                          563            553            1116
# 3                                          614            594            1208
# 4                                          531            524            1055
#
#    2017_act_participation  2017_act_english  2017_act_math  2017_act_reading  \
# 0                   100.0              18.9           18.4              19.7
# 1                    65.0              18.7           19.8              20.4
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
# report.to_csv('report.csv')
combined_2017.to_csv('combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Read in the `sat_2018.csv` and `act_2018.csv` files and assign them to appropriately named pandas dataframes. For the **2018 ACT Data**, only the `Composite` scores are available. Repeat the same processes to clean the 2018 data here as you were instructed in the previous sections above.

# %%
sat_2018 = pd.read_csv('/Users/aidancurley/Documents/dsir/Submissions/Projects/project-1-master/data/sat_2018.csv')
act_2018 = pd.read_csv('/Users/aidancurley/Documents/dsir/Submissions/Projects/project-1-master/data/act_2018.csv')

# %%
sat_2018.shape
# Out:
# (51, 5)

# %%
act_2018.shape
# Out:
# (51, 3)

# %%
# There are no values that seem out of place or not possible
sat_2018.describe()
# Out:
#        2018_sat_participation  2018_sat_evidence_based_reading_and_writing  \
# count               51.000000                                    51.000000
# mean                45.745098                                   563.686275
# std                 37.314256                                    47.502627
# min                  2.000000                                   480.000000
# 25%                  4.500000                                   534.500000
# 50%                 52.000000                                   552.000000
# 75%                 77.500000                                   610.500000
# max                100.000000                                   643.000000
#
#        2018_sat_math  2018_sat_total
# count      51.000000       51.000000
# mean      556.235294     1120.019608
# std        47.772623       94.155083
# min       480.000000      977.000000
# 25%       522.500000     1057.500000
# 50%       544.000000     1098.000000
# ...

# %%
# There are no values that seem out of place or not possible
act_2018.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000

# %%
# Participation has to become a float
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# Participation has to become a float
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
# Updating the values in the 'Participation' column
sat_2018['Participation'] = sat_2018['Participation'].map(lambda x: float(x[:-1]))

# %%
# Updating the values in the 'Participation' column
act_2018['Participation'] = act_2018['Participation'].map(lambda x: float(x[:-1]))

# %%
act_2018.dtypes
# Out:
# 2018_state                 object
# 2018_act_participation    float64
# 2018_act_composite        float64
# dtype: object

# %%
# Now I need to get rid of the error
# There is an extra row in the act_2018 dataset. Maine was put in twice
act_2018.shape
# Out:
# (52, 3)

# %%
act_2018 = act_2018.drop_duplicates()

# %%
# Now it has the appropriate amount of columns
act_2018.shape
# Out:
# (51, 3)

# %%
sat_2018.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
sat_2018.columns = sat_2018.columns.str.lower()
sat_2018.columns
# Out:
# Index(['state', 'participation', 'evidence-based reading and writing', 'math',
#        'total'],
#       dtype='object')

# %%
# Renaming the sat_2018 columns
sat_2018.rename(columns={'state': 'sat_state',
                         'participation': 'sat_participation',
                         'evidence-based reading and writing': 'sat_evidence_based_reading_and_writing',
                         'math': 'sat_math',
                         'total': 'sat_total'
                    }, inplace=True)

# %%
sat_2018.head(1)
# Out:
#   2018_state  2018_sat_participation  \
# 0    Alabama                     6.0
#
#    2018_sat_evidence_based_reading_and_writing  2018_sat_math  2018_sat_total
# 0                                          595            571            1166

# %%
sat_2018.rename(columns={'2018_state': 'state'
                         
                    }, inplace=True)

# %%
act_2018.columns = act_2018.columns.str.lower()
act_2018.columns
# Out:
# Index(['state', 'participation', 'composite'], dtype='object')

# %%
act_2018.rename(columns={'2018_state': 'state',
                       
                    }, inplace=True)

# %%
act_2018.head(3)
# Out:
#      state  2018_act_participation  2018_act_composite
# 0  Alabama                   100.0                19.1
# 1   Alaska                    33.0                20.8
# 2  Arizona                    66.0                19.2

# %%
act_2018.columns
# Out:
# Index(['act_state', 'act_participation', 'act_composite'], dtype='object')

# %%
act_2018.rename(columns={'act_state': '2018_state',
                         'act_participation': '2018_act_participation',
                         'act_composite': '2018_act_composite'
                    }, inplace=True)

# %%
# Updating the improper value of math
# act_2017.at[20, 'Math'] = 524

# %%
act_2018['2018_state'][8]
# Out:
# 'District of columbia'

# %%
act_2018.at[8, '2018_state'] = 'District of Columbia'

# %%
sat_2018.rename(columns={'sat_state': '2018_state',
                         'sat_participation': '2018_sat_participation',
                         'sat_evidence_based_reading_and_writing': '2018_sat_evidence_based_reading_and_writing',
                         'sat_math': '2018_sat_math',
                         'sat_total': '2018_sat_total'
                    }, inplace=True)

# %%
sat_2018.head()
# Out:
#         state  2018_sat_participation  \
# 0     Alabama                     6.0
# 1      Alaska                    43.0
# 2     Arizona                    29.0
# 3    Arkansas                     5.0
# 4  California                    60.0
#
#    2018_sat_evidence_based_reading_and_writing  2018_sat_math  2018_sat_total
# 0                                          595            571            1166
# 1                                          562            544            1106
# 2                                          577            572            1149
# 3                                          592            576            1169
# 4                                          540            536            1076

# %%
combined_2018 = pd.merge(sat_2018, act_2018, on='state')
combined_2018.head(1)
# Out:
#      state  2018_sat_participation  \
# 0  Alabama                     6.0
#
#    2018_sat_evidence_based_reading_and_writing  2018_sat_math  2018_sat_total  \
# 0                                          595            571            1166
#
#    2018_act_participation  2018_act_composite
# 0                   100.0                19.1

# %%
combined_2018.columns
# Out:
# Index(['state', '2018_sat_participation',
#        '2018_sat_evidence_based_reading_and_writing', '2018_sat_math',
#        '2018_sat_total', '2018_act_participation', '2018_act_composite'],
#       dtype='object')

# %%
combined_2018.rename(columns={'2018_state': 'state'}, inplace=True)

# %%
combined_2017.columns
# Out:
# Index(['2017_state', '2017_sat_participation',
#        'evidence-based reading and writing', '2017_sat_math', '2017_sat_total',
#        '2017_act_participation', '2017_act_english', '2017_act_math',
#        '2017_act_reading', '2017_act_science', '2017_act_composite'],
#       dtype='object')

# %%
combined_2017.rename(columns={'2017_state': 'state'}, inplace=True)

# %%
combined_2017.columns
# Out:
# Index(['state', '2017_sat_participation', 'evidence-based reading and writing',
#        '2017_sat_math', '2017_sat_total', '2017_act_participation',
#        '2017_act_english', '2017_act_math', '2017_act_reading',
#        '2017_act_science', '2017_act_composite'],
#       dtype='object')

# %%
combined_2018.head(1)
# Out:
#      state  2018_sat_participation  \
# 0  Alabama                     6.0
#
#    2018_sat_evidence_based_reading_and_writing  2018_sat_math  2018_sat_total  \
# 0                                          595            571            1166
#
#    2018_act_participation  2018_act_composite
# 0                   100.0                19.1

# %%
combined_2018.to_csv('combined_2018.csv')

# %% [markdown]
# # Data dictionary for ACT and SAT data in 2018
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|object|sat_2018|All 50 states and the District of Columbia|
# |**2018_sat_participation**|float|sat_2018|The overall percentage of people taking the SAT in that state in 2018|
# |**2018_sat_evidence_based_reading_and_writing**|int|sat_2018|The average score for the evidence-based reading and writing section of the SAT for each state |
# |**2018_sat_math**|int|sat_2018|The average score for the math section of the SAT for each state|
# |**2018_sat_total**|int|sat_2018|The overall average total score of the SAT for each state |
# |**state**|object|act_2018|All 50 states and the District of Columbia|
# |**2018_act_participation**|float|act_2018|The overall percentage of people taking the ACT in that state in 2018|
# |**2018_act_composite**|float|act_2018|The average score on the ACT for each state and the national average score|

# %%
combined_2017.head(1)
# Out:
#      state  2017_sat_participation  \
# 0  Alabama                     5.0
#
#    2017_sat_evidence_based_reading_and_writing  2017_sat_math  2017_sat_total  \
# 0                                          593            572            1165
#
#    2017_act_participation  2017_act_english  2017_act_math  2017_act_reading  \
# 0                   100.0              18.9           18.4              19.7
#
#    2017_act_science  2017_act_composite
# 0              19.4                19.2

# %%
combined_2018.head(1)
# Out:
#      state  2018_sat_participation  \
# 0  Alabama                     6.0
#
#    2018_sat_evidence_based_reading_and_writing  2018_sat_math  2018_sat_total  \
# 0                                          595            571            1166
#
#    2018_act_participation  2018_act_composite
# 0                   100.0                19.1

# %% [markdown]
# ### 2019 Data

# %%
act_2019 = pd.read_csv('/Users/aidancurley/Documents/dsir/Submissions/Projects/project-1-master/data/act_2019.csv', encoding='latin1')
sat_2019 = pd.read_csv('/Users/aidancurley/Documents/dsir/Submissions/Projects/project-1-master/data/sat_2019.csv', encoding='latin1')

# %%
# 51
sat_2019.shape
# Out:
# (53, 5)

# %%
# 40 and 47
act_2019.shape
# Out:
# (52, 3)

# %%
# Nothing seems out of the ordinary
sat_2019.describe()
# Out:
#              EBRW        Math        Total
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# min    483.000000  445.000000   935.000000
# 25%    518.000000  506.000000  1024.000000
# 50%    550.000000  545.000000  1097.000000
# 75%    610.000000  596.000000  1200.000000
# max    636.000000  648.000000  1284.000000

# %%
act_2019.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.450000
# std     2.175487
# min    17.900000
# 25%    19.800000
# 50%    20.950000
# 75%    23.650000
# max    25.500000

# %%
# There are no null value
# Participation dtype has to be changed
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
# There are no null values
# Participation has to be changed to a float
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
act_2019.head(1)
# Out:
#      state  2019_act_participation  2019_act_composite
# 0  Alabama                   100.0                18.9

# %%
sat_2019.columns
# Out:
# Index(['State', 'Participation Rate', 'EBRW', 'Math', 'Total'], dtype='object')

# %%
sat_2019.head(1)
# Out:
#      state  2019_sat_participation  \
# 0  Alabama                     7.0
#
#    2019_sat_evidence_based_reading_and_writing  2019_sat_math  2019_sat_total
# 0                                          583            560            1143

# %%
# Before changing the dtype in 'Participation' we need to drop two rows
sat_2019 = sat_2019[sat_2019['State'] != 'Puerto Rico']
sat_2019 = sat_2019[sat_2019['State'] != 'Virgin Islands']

# %%
# Puerto Rico and the Virgin Islands are now dropped
sat_2019.shape
# Out:
# (51, 5)

# %%
# Updating the values in the 'Participation Rate' column

sat_2019['Participation Rate'] = sat_2019['Participation Rate'].map(lambda x: float(x[:-1]))

# %%
# Updating the values in the 'Participation' column
act_2019['Participation'] = act_2019['Participation'].map(lambda x: float(x[:-1]))

# %%
act_2019.tail(1)
# Out:
#       state  2019_act_participation  2019_act_composite
# 50  Wyoming                   100.0                19.8

# %%
# Dropping the unnecessary row
# act_2019.drop([act_2019.index[-1]], inplace=True)

# %%
# Same rows as the sat_2019 dataset
act_2019.shape
# Out:
# (51, 3)

# %%
# Same rows as the act_2019 dataset
sat_2019.shape
# Out:
# (51, 5)

# %%
sat_2019.columns
# Out:
# Index(['State', 'Participation Rate', 'EBRW', 'Math', 'Total'], dtype='object')

# %%
# Now we need to rename columns for sat_2019
sat_2019.rename(columns={'State': 'state',
                         'Participation Rate': '2019_sat_participation',
                         'EBRW': '2019_sat_evidence_based_reading_and_writing',
                         'Math': '2019_sat_math',
                         'Total': '2019_sat_total'
                    }, inplace=True)

# %%
# Now we need to rename columnds for act_2019
act_2019.rename(columns={'State': 'state',
                         'Participation': '2019_act_participation',
                         'Composite': '2019_act_composite'           
                    }, inplace=True)

# %%
combined_2019 = pd.merge(act_2019, sat_2019, on='state')

# %%
combined_2019.head(1)
# Out:
#      state  2019_act_participation  2019_act_composite  \
# 0  Alabama                   100.0                18.9
#
#    2019_sat_participation  2019_sat_evidence_based_reading_and_writing  \
# 0                     7.0                                          583
#
#    2019_sat_math  2019_sat_total
# 0            560            1143

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
combined_2017.head(1)
# Out:
#      state  2017_sat_participation  \
# 0  Alabama                     5.0
#
#    2017_sat_evidence_based_reading_and_writing  2017_sat_math  2017_sat_total  \
# 0                                          593            572            1165
#
#    2017_act_participation  2017_act_english  2017_act_math  2017_act_reading  \
# 0                   100.0              18.9           18.4              19.7
#
#    2017_act_science  2017_act_composite
# 0              19.4                19.2

# %%
combined_2018.head(1)
# Out:
#      state  2018_sat_participation  \
# 0  Alabama                     6.0
#
#    2018_sat_evidence_based_reading_and_writing  2018_sat_math  2018_sat_total  \
# 0                                          595            571            1166
#
#    2018_act_participation  2018_act_composite
# 0                   100.0                19.1

# %%
# Merging 2017 and 2018
final = pd.merge(combined_2017, combined_2018, on='state') 
final.dtypes
# Out:
# state                                           object
# 2017_sat_participation                         float64
# 2017_sat_evidence_based_reading_and_writing      int64
# 2017_sat_math                                    int64
# 2017_sat_total                                   int64
# 2017_act_participation                         float64
# 2017_act_english                               float64
# 2017_act_math                                  float64
# 2017_act_reading                               float64
# 2017_act_science                               float64
# 2017_act_composite                             float64
# 2018_sat_participation                         float64
# 2018_sat_evidence_based_reading_and_writing      int64
# 2018_sat_math                                    int64
# 2018_sat_total                                   int64
# 2018_act_participation                         float64
# 2018_act_composite                             float64
# dtype: object

# %%
# Merging the merged 2017 and 2018 with combined_2019
final = pd.merge(final, combined_2019, on='state')

# %%
final.dtypes
# Out:
# state                                           object
# 2017_sat_participation                         float64
# 2017_sat_evidence_based_reading_and_writing      int64
# 2017_sat_math                                    int64
# 2017_sat_total                                   int64
# 2017_act_participation                         float64
# 2017_act_english                               float64
# 2017_act_math                                  float64
# 2017_act_reading                               float64
# 2017_act_science                               float64
# 2017_act_composite                             float64
# 2018_sat_participation                         float64
# 2018_sat_evidence_based_reading_and_writing      int64
# 2018_sat_math                                    int64
# 2018_sat_total                                   int64
# 2018_act_participation                         float64
# 2018_act_composite                             float64
# ...

# %%
final.to_csv('final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
final.describe().T
# Out:
#                                              count         mean        std  \
# 2017_sat_participation                        51.0    39.803922  35.276632
# 2017_sat_evidence_based_reading_and_writing   51.0   569.117647  45.666901
# 2017_sat_math                                 51.0   556.882353  47.121395
# 2017_sat_total                                51.0  1126.098039  92.494812
# 2017_act_participation                        51.0    65.254902  32.140842
# 2017_act_english                              51.0    20.931373   2.353677
# 2017_act_math                                 51.0    21.182353   1.981989
# 2017_act_reading                              51.0    22.013725   2.067271
# 2017_act_science                              51.0    21.450980   1.739353
# 2017_act_composite                            51.0    21.519608   2.020695
# 2018_sat_participation                        51.0    45.745098  37.314256
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
from math import sqrt

# %%
# Haley Taft, James Pecore, Lydia Kajeckas, and Eric Heidbreder contributed to this code
def std(num):
    mean = sum(num) / len(num)
    variance = 0
    for n in num:
        variance += (n-mean)**2
    variance /= len(num)
    
    return sqrt(variance)

nums = [2, 3, 4, 5, 6, 7, 8 ,9 , 0]
std(nums) # Our functions results
# Out:
# 2.7666443551086073

# %%
np.std(nums) # Numpy's std method results
# Out:
# 2.7666443551086073

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
final[['2017_sat_participation']].apply(std)
# Out:
# 2017_sat_participation    34.929071
# dtype: float64

# %%
#Code:
# Haley Taft contributed to this code
{x: std(final[x]) for x in final.columns[1:]}
# Out:
# {'2017_sat_participation': 34.92907076664508,
#  '2017_sat_evidence_based_reading_and_writing': 45.21697020437866,
#  '2017_sat_math': 46.65713364485503,
#  '2017_sat_total': 91.58351056778743,
#  '2017_act_participation': 31.824175751231806,
#  '2017_act_english': 2.3304876369363363,
#  '2017_act_math': 1.9624620273436781,
#  '2017_act_reading': 2.0469029314842646,
#  '2017_act_science': 1.7222161451443676,
#  '2017_act_composite': 2.000786081581989,
#  '2018_sat_participation': 36.946619223539415,
#  '2018_sat_evidence_based_reading_and_writing': 47.03460978357609,
#  '2018_sat_math': 47.30194550378352,
#  '2018_sat_total': 93.22742384464433,
#  '2018_act_participation': 33.70173582041031,
#  '2018_act_composite': 2.090779082141178,
#  '2019_act_participation': 34.17582373703048,
#  '2019_act_composite': 2.172901153595978,
#  '2019_sat_participation': 38.365840486857266,
#  '2019_sat_evidence_based_reading_and_writing': 45.792378682545134,
#  '2019_sat_math': 50.78521461840036,
# ...

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# **Answer:***
# In comparsion between the dictionary comprehension I created and the pandas describe method the standard deviation is very close. There is a couple of points of difference however the numbers are very close. Also using numpy's std method our calculations were very close.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?

# %%
# 2017 SAT lowest participation rates
final.sort_values('2017_sat_participation').head()
# Out:
#            state  2017_sat_participation  \
# 34  North Dakota                     2.0
# 24   Mississippi                     2.0
# 15          Iowa                     2.0
# 25      Missouri                     3.0
# 44          Utah                     3.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 34                                          635            621
# 24                                          634            607
# 15                                          641            635
# 25                                          640            631
# 44                                          624            614
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 34            1256                    98.0              19.0           20.4
# 24            1242                   100.0              18.2           18.1
# 15            1275                    67.0              21.2           21.3
# ...

# %% [markdown]
# The states with the lowest participation rates for he 2017 SAT are
# North Dakota, Mississippi, Iowa with a particiaption rate of 2.0%

# %%
# 2017 SAT highest participation rates
final.sort_values('2017_sat_participation').tail()
# Out:
#                    state  2017_sat_participation  \
# 29         New Hampshire                    96.0
# 22              Michigan                   100.0
# 8   District of Columbia                   100.0
# 7               Delaware                   100.0
# 6            Connecticut                   100.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 29                                          532            520
# 22                                          509            495
# 8                                           482            468
# 7                                           503            492
# 6                                           530            512
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 29            1052                    18.0              25.4           25.1
# 22            1005                    29.0              24.1           23.7
# ...

# %% [markdown]
# The states with the highest participation rates for the 2017 SAT are
# Michigan, District of Columbia, Delaware, and Connecticut with a particiaption rate of 100.0%

# %%
# 2017 ACT lowest participation rate
final.sort_values('2017_act_participation').head()
# Out:
#             state  2017_sat_participation  \
# 19          Maine                    95.0
# 29  New Hampshire                    96.0
# 7        Delaware                   100.0
# 39   Rhode Island                    71.0
# 38   Pennsylvania                    65.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 19                                          513            499
# 29                                          532            520
# 7                                           503            492
# 39                                          539            524
# 38                                          540            531
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 19            1012                     8.0              24.2           24.0
# 29            1052                    18.0              25.4           25.1
# 7              996                    18.0              24.1           23.4
# ...

# %% [markdown]
# The state with the lowest participation rate for the 2017 ACT is
# Maine with a particiaption rate of 8.0%

# %%
# 2017 ACT highest participation rates
final.sort_values('2017_act_participation').tail(20)
# Out:
#              state  2017_sat_participation  \
# 11          Hawaii                    55.0
# 13        Illinois                     9.0
# 34    North Dakota                     2.0
# 40  South Carolina                    50.0
# 44            Utah                     3.0
# 42       Tennessee                     5.0
# 0          Alabama                     5.0
# 25        Missouri                     3.0
# 33  North Carolina                    49.0
# 28          Nevada                    26.0
# 26         Montana                    10.0
# 49       Wisconsin                     3.0
# 24     Mississippi                     2.0
# 23       Minnesota                     3.0
# 18       Louisiana                     4.0
# 17        Kentucky                     4.0
# 5         Colorado                    11.0
# 3         Arkansas                     3.0
# 36        Oklahoma                     7.0
# 50         Wyoming                     3.0
#
# ...

# %% [markdown]
# The states with the highest participation rates for the 2017 ACT is
# South Carolina, Utah, Tennessee, Alabama, Missouri, North Carolina, Nevada, Montana, Wisconsin, Mississippi,
# Minnesota, Louisiana, Kentucky, Colorado, Arkansas, Oklahoma, Wyoming
# with a particiaption rate of 100.0%

# %%
# 2018 SAT lowest participation rates
final.sort_values('2018_sat_participation').head()
# pd.set_option('display.max_columns', 999)
# Out:
#            state  2017_sat_participation  \
# 34  North Dakota                     2.0
# 50       Wyoming                     3.0
# 41  South Dakota                     3.0
# 27      Nebraska                     3.0
# 49     Wisconsin                     3.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 34                                          635            621
# 50                                          626            604
# 41                                          612            603
# 27                                          629            625
# 49                                          642            649
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 34            1256                    98.0              19.0           20.4
# 50            1230                   100.0              19.4           19.8
# 41            1216                    80.0              20.7           21.5
# ...

# %% [markdown]
# The state with the lowest participation rates for the 2018 SAT is
# North Dakota with a particiaption rate of 2.0

# %%
# 2018 SAT highest participation rates
final.sort_values('2018_sat_participation').tail(14)
# pd.set_option('display.max_columns', 999)
# Out:
#                    state  2017_sat_participation  \
# 20              Maryland                    69.0
# 32              New York                    67.0
# 21         Massachusetts                    76.0
# 30            New Jersey                    70.0
# 8   District of Columbia                   100.0
# 29         New Hampshire                    96.0
# 39          Rhode Island                    71.0
# 19                 Maine                    95.0
# 13              Illinois                     9.0
# 5               Colorado                    11.0
# 6            Connecticut                   100.0
# 7               Delaware                   100.0
# 22              Michigan                   100.0
# 12                 Idaho                    93.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 20                                          536            524
# 32                                          528            523
# ...

# %% [markdown]
# The states with the highest participation rates for the 2018 SAT are
# Colorado, Connecticut, Delaware, Michigan, Idaho

# %%
# 2018 ACT lowest participation rates
final.sort_values('2018_act_participation').head(2)
# pd.set_option('display.max_columns', 999)
# Out:
#            state  2017_sat_participation  \
# 19         Maine                    95.0
# 39  Rhode Island                    71.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 19                                          513            499
# 39                                          539            524
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 19            1012                     8.0              24.2           24.0
# 39            1062                    21.0              24.0           23.3
#
#     2017_act_reading  2017_act_science  2017_act_composite  \
# 19              24.8              23.7                24.3
# 39              24.7              23.4                24.0
#
#     2018_sat_participation  2018_sat_evidence_based_reading_and_writing  \
# 19                    99.0                                          512
# 39                    97.0                                          513
#
# ...

# %% [markdown]
# The states with the lowest participation rates for the 2018 ACT is
# Maine with a participation rate of 7.0

# %%
# 2018 ACT highest participation rates
final.sort_values('2018_act_participation').tail(20)
# Out:
#              state  2017_sat_participation  \
# 11          Hawaii                    55.0
# 34    North Dakota                     2.0
# 23       Minnesota                     3.0
# 42       Tennessee                     5.0
# 44            Utah                     3.0
# 40  South Carolina                    50.0
# 0          Alabama                     5.0
# 25        Missouri                     3.0
# 35            Ohio                    12.0
# 33  North Carolina                    49.0
# 28          Nevada                    26.0
# 27        Nebraska                     3.0
# 26         Montana                    10.0
# 49       Wisconsin                     3.0
# 24     Mississippi                     2.0
# 18       Louisiana                     4.0
# 17        Kentucky                     4.0
# 3         Arkansas                     3.0
# 36        Oklahoma                     7.0
# 50         Wyoming                     3.0
#
# ...

# %% [markdown]
# The states with the highest participation rates for the 2018 ACT are
# Tennessee, Utah, South Carolina, Alabama, Missouri, Ohio, North Carolina, Nevada, Nebraska,
# Montana, Wisonsin, Mississippi, Louisiana, Kentucky, Arkansas, Oklahoma, Wyoming
# with a participation rate of 100.0%

# %%
# 2019 SAT lowest participation rate 
final.sort_values('2019_sat_participation').head(5)
# Out:
#            state  2017_sat_participation  \
# 34  North Dakota                     2.0
# 50       Wyoming                     3.0
# 41  South Dakota                     3.0
# 27      Nebraska                     3.0
# 49     Wisconsin                     3.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 34                                          635            621
# 50                                          626            604
# 41                                          612            603
# 27                                          629            625
# 49                                          642            649
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 34            1256                    98.0              19.0           20.4
# 50            1230                   100.0              19.4           19.8
# 41            1216                    80.0              20.7           21.5
# ...

# %% [markdown]
# The state with the lowest participation rate for the 2019 SAT is
# North Dakota with a particiaption rate of 2.0%

# %%
# 2019 SAT
final.sort_values('2019_sat_participation').tail(10)
# Out:
#             state  2017_sat_participation  \
# 48  West Virginia                    14.0
# 19          Maine                    95.0
# 9         Florida                    83.0
# 39   Rhode Island                    71.0
# 5        Colorado                    11.0
# 6     Connecticut                   100.0
# 7        Delaware                   100.0
# 22       Michigan                   100.0
# 13       Illinois                     9.0
# 12          Idaho                    93.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 48                                          558            528
# 19                                          513            499
# 9                                           520            497
# 39                                          539            524
# 5                                           606            595
# 6                                           530            512
# ...

# %% [markdown]
# The states with the highest participation rate for the 2019 SAT are
# Florida, Rhode Island, Colorado, Connecticut, Delaware, Michigan, Illinois, Idaho
# with a particiaption rate of 100.0%%

# %%
# 2019 ACT
final.sort_values('2019_act_participation').head(2)
# Out:
#            state  2017_sat_participation  \
# 19         Maine                    95.0
# 39  Rhode Island                    71.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 19                                          513            499
# 39                                          539            524
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 19            1012                     8.0              24.2           24.0
# 39            1062                    21.0              24.0           23.3
#
#     2017_act_reading  2017_act_science  2017_act_composite  \
# 19              24.8              23.7                24.3
# 39              24.7              23.4                24.0
#
#     2018_sat_participation  2018_sat_evidence_based_reading_and_writing  \
# 19                    99.0                                          512
# 39                    97.0                                          513
#
# ...

# %% [markdown]
# The state with the lowest participation rate for the 2019 ACT is
# Maine with a particiaption rate of 6.0%

# %%
# 2019 SAT
final.sort_values('2019_act_participation').tail(5)
# Out:
#         state  2017_sat_participation  \
# 18  Louisiana                     4.0
# 17   Kentucky                     4.0
# 3    Arkansas                     3.0
# 36   Oklahoma                     7.0
# 50    Wyoming                     3.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 18                                          611            586
# 17                                          631            616
# 3                                           614            594
# 36                                          530            517
# 50                                          626            604
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 18            1198                   100.0              19.4           18.8
# 17            1247                   100.0              19.6           19.4
# 3             1208                   100.0              18.9           19.0
# ...

# %% [markdown]
# The states with the highest participation rate for the 2019 ACT are
# Utah, Tennessee, Alabama, Ohio, North Carolina, Nevada, Montana, Wisconsin, Mississippi,
# Louisiana, Kentucky, Arkansas, Oklahoma, Wyoming with a particiaption rate of 100.0%

# %% [markdown]
# Which states have the highest and lowest mean total/composite scores for the:
# 2017 SAT?
# 2018 SAT?
# 2017 ACT?
# 2018 ACT?

# %%
# 2017 SAT lowest mean total
final.sort_values('2017_sat_total').head(2)
# Out:
#                   state  2017_sat_participation  \
# 8  District of Columbia                   100.0
# 7              Delaware                   100.0
#
#    2017_sat_evidence_based_reading_and_writing  2017_sat_math  2017_sat_total  \
# 8                                          482            468             950
# 7                                          503            492             996
#
#    2017_act_participation  2017_act_english  2017_act_math  2017_act_reading  \
# 8                    32.0              24.4           23.5              24.9
# 7                    18.0              24.1           23.4              24.8
#
#    2017_act_science  2017_act_composite  2018_sat_participation  \
# 8              23.5                24.2                    92.0
# 7              23.6                24.1                   100.0
#
#    2018_sat_evidence_based_reading_and_writing  2018_sat_math  2018_sat_total  \
# ...

# %% [markdown]
# The state with the lowest mean total for the 2017 SAT is
# District of Columbia with a mean total of 950

# %%
# 2017 SAT highest mean total
final.sort_values('2017_sat_total').tail(2)
# Out:
#         state  2017_sat_participation  \
# 49  Wisconsin                     3.0
# 23  Minnesota                     3.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 49                                          642            649
# 23                                          644            651
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 49            1291                   100.0              19.7           20.4
# 23            1295                   100.0              20.4           21.5
#
#     2017_act_reading  2017_act_science  2017_act_composite  \
# 49              20.6              20.9                20.5
# 23              21.8              21.6                21.5
#
#     2018_sat_participation  2018_sat_evidence_based_reading_and_writing  \
# 49                     3.0                                          641
# 23                     4.0                                          643
#
# ...

# %% [markdown]
# The state with the highest mean total for the 2017 SAT is
# Minnesota with a mean total of 1295

# %%
# 2017 ACT lowest mean composite
final.sort_values('2017_act_composite').head(2)
# Out:
#           state  2017_sat_participation  \
# 28       Nevada                    26.0
# 24  Mississippi                     2.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 28                                          563            553
# 24                                          634            607
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 28            1116                   100.0              16.3           18.0
# 24            1242                   100.0              18.2           18.1
#
#     2017_act_reading  2017_act_science  2017_act_composite  \
# 28              18.1              18.2                17.8
# 24              18.8              18.8                18.6
#
#     2018_sat_participation  2018_sat_evidence_based_reading_and_writing  \
# 28                    23.0                                          574
# 24                     3.0                                          630
#
# ...

# %% [markdown]
# The state with the lowest mean composite for the 2017 ACT is
# Nevada with a mean composite of 17.8

# %%
# 2017 ACT highest mean composite
final.sort_values('2017_act_composite').tail(2)
# Out:
#             state  2017_sat_participation  \
# 21  Massachusetts                    76.0
# 29  New Hampshire                    96.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 21                                          555            551
# 29                                          532            520
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 21            1107                    29.0              25.4           25.3
# 29            1052                    18.0              25.4           25.1
#
#     2017_act_reading  2017_act_science  2017_act_composite  \
# 21              25.9              24.7                25.4
# 29              26.0              24.9                25.5
#
#     2018_sat_participation  2018_sat_evidence_based_reading_and_writing  \
# 21                    80.0                                          562
# 29                    96.0                                          535
#
# ...

# %% [markdown]
# The state with the highest mean composite for the 2017 ACT is
# New Hampshire with a mean composite of 25.5

# %%
# 2018 SAT lowest mean total
final.sort_values('2018_sat_total').head(2)
# Out:
#                   state  2017_sat_participation  \
# 8  District of Columbia                   100.0
# 7              Delaware                   100.0
#
#    2017_sat_evidence_based_reading_and_writing  2017_sat_math  2017_sat_total  \
# 8                                          482            468             950
# 7                                          503            492             996
#
#    2017_act_participation  2017_act_english  2017_act_math  2017_act_reading  \
# 8                    32.0              24.4           23.5              24.9
# 7                    18.0              24.1           23.4              24.8
#
#    2017_act_science  2017_act_composite  2018_sat_participation  \
# 8              23.5                24.2                    92.0
# 7              23.6                24.1                   100.0
#
#    2018_sat_evidence_based_reading_and_writing  2018_sat_math  2018_sat_total  \
# ...

# %% [markdown]
# The state with the lowest mean total for the 2018 SAT is
# District of Columbia with a mean total of 977

# %%
# 2018 SAT highest mean total
final.sort_values('2018_sat_total').tail(2)
# Out:
#         state  2017_sat_participation  \
# 49  Wisconsin                     3.0
# 23  Minnesota                     3.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 49                                          642            649
# 23                                          644            651
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 49            1291                   100.0              19.7           20.4
# 23            1295                   100.0              20.4           21.5
#
#     2017_act_reading  2017_act_science  2017_act_composite  \
# 49              20.6              20.9                20.5
# 23              21.8              21.6                21.5
#
#     2018_sat_participation  2018_sat_evidence_based_reading_and_writing  \
# 49                     3.0                                          641
# 23                     4.0                                          643
#
# ...

# %% [markdown]
# The state with the lowest mean total for the 2018 SAT is
# Minnesota with a mean total of 1298

# %%
# 2018 ACT lowest mean composite
final.sort_values('2018_act_composite').head(2)
# Out:
#              state  2017_sat_participation  \
# 28          Nevada                    26.0
# 40  South Carolina                    50.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 28                                          563            553
# 40                                          543            521
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 28            1116                   100.0              16.3           18.0
# 40            1064                   100.0              17.5           18.6
#
#     2017_act_reading  2017_act_science  2017_act_composite  \
# 28              18.1              18.2                17.8
# 40              19.1              18.9                18.7
#
#     2018_sat_participation  2018_sat_evidence_based_reading_and_writing  \
# 28                    23.0                                          574
# 40                    55.0                                          547
#
# ...

# %% [markdown]
# The state with the lowest mean composite for the 2018 ACT is
# Nevada with a mean composite of 17.7

# %%
# 2018 ACT highest mean composite
final.sort_values('2018_act_composite').tail(2)
# Out:
#             state  2017_sat_participation  \
# 21  Massachusetts                    76.0
# 6     Connecticut                   100.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 21                                          555            551
# 6                                           530            512
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 21            1107                    29.0              25.4           25.3
# 6             1041                    31.0              25.5           24.6
#
#     2017_act_reading  2017_act_science  2017_act_composite  \
# 21              25.9              24.7                25.4
# 6               25.6              24.6                25.2
#
#     2018_sat_participation  2018_sat_evidence_based_reading_and_writing  \
# 21                    80.0                                          562
# 6                    100.0                                          535
#
# ...

# %% [markdown]
# The state with the highest mean composite for the 2018 ACT is
# Connecticut with a mean composite of 25.6

# %%
# 2019 SAT lowest mean total
final.sort_values('2019_sat_total').head(2)
# Out:
#             state  2017_sat_participation  \
# 48  West Virginia                    14.0
# 36       Oklahoma                     7.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 48                                          558            528
# 36                                          530            517
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 48            1086                    69.0              20.0           19.4
# 36            1047                   100.0              18.5           18.8
#
#     2017_act_reading  2017_act_science  2017_act_composite  \
# 48              21.2              20.5                20.4
# 36              20.1              19.6                19.4
#
#     2018_sat_participation  2018_sat_evidence_based_reading_and_writing  \
# 48                    28.0                                          513
# 36                     8.0                                          541
#
# ...

# %% [markdown]
# The state with the lowest mean total for the 2019 SAT is
# West Virginia with a mean total of 943

# %%
# 2019 SAT highest mean total
final.sort_values('2019_sat_total').tail(2)
# Out:
#         state  2017_sat_participation  \
# 49  Wisconsin                     3.0
# 23  Minnesota                     3.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 49                                          642            649
# 23                                          644            651
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 49            1291                   100.0              19.7           20.4
# 23            1295                   100.0              20.4           21.5
#
#     2017_act_reading  2017_act_science  2017_act_composite  \
# 49              20.6              20.9                20.5
# 23              21.8              21.6                21.5
#
#     2018_sat_participation  2018_sat_evidence_based_reading_and_writing  \
# 49                     3.0                                          641
# 23                     4.0                                          643
#
# ...

# %% [markdown]
# The state with the highest mean total for the 2019 SAT is
# Minnesota with a mean total of 1284

# %%
# 2019 ACT lowest mean composite
final.sort_values('2019_act_composite').head(2)
# Out:
#           state  2017_sat_participation  \
# 28       Nevada                    26.0
# 24  Mississippi                     2.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 28                                          563            553
# 24                                          634            607
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 28            1116                   100.0              16.3           18.0
# 24            1242                   100.0              18.2           18.1
#
#     2017_act_reading  2017_act_science  2017_act_composite  \
# 28              18.1              18.2                17.8
# 24              18.8              18.8                18.6
#
#     2018_sat_participation  2018_sat_evidence_based_reading_and_writing  \
# 28                    23.0                                          574
# 24                     3.0                                          630
#
# ...

# %% [markdown]
# The state with the lowest mean composite for the 2019 ACT is
# Nevada with a mean composite of 17.9

# %%
# 2019 ACT highest mean composite
final.sort_values('2019_act_composite').tail(3)
# Out:
#             state  2017_sat_participation  \
# 29  New Hampshire                    96.0
# 6     Connecticut                   100.0
# 21  Massachusetts                    76.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 29                                          532            520
# 6                                           530            512
# 21                                          555            551
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 29            1052                    18.0              25.4           25.1
# 6             1041                    31.0              25.5           24.6
# 21            1107                    29.0              25.4           25.3
#
#     2017_act_reading  2017_act_science  2017_act_composite  \
# 29              26.0              24.9                25.5
# 6               25.6              24.6                25.2
# ...

# %% [markdown]
# The states with the highst mean composite for the 2019 ACT are
# Connecticut and Massachusetts with a mean composite of 25.5

# %% [markdown]
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# ACT 100% 2017 -> 2018
final[(final['2017_act_participation'] == 100) & (final['2018_act_participation'] < 100)]
# Out:
#         state  2017_sat_participation  \
# 5    Colorado                    11.0
# 23  Minnesota                     3.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 5                                           606            595
# 23                                          644            651
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 5             1201                   100.0              20.1           20.3
# 23            1295                   100.0              20.4           21.5
#
#     2017_act_reading  2017_act_science  2017_act_composite  \
# 5               21.2              20.9                20.8
# 23              21.8              21.6                21.5
#
#     2018_sat_participation  2018_sat_evidence_based_reading_and_writing  \
# 5                    100.0                                          519
# 23                     4.0                                          643
#
# ...

# %% [markdown]
# Colorado and Minnesota had 100% participation for the ACT in 2017 but did not have 100% participation for the ACT in 2018.
# Colorado had a 70% decrease in ACT participation between 2017 and 2018. Minnesota had a 1% decrease in ACT particiaption between 2017 and 2018

# %%
# ACT 100% 2018 -> 2019
final[(final['2018_act_participation'] == 100) & (final['2019_act_participation'] < 100)]
# Out:
#              state  2017_sat_participation  \
# 25        Missouri                     3.0
# 40  South Carolina                    50.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 25                                          640            631
# 40                                          543            521
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 25            1271                   100.0              19.8           19.9
# 40            1064                   100.0              17.5           18.6
#
#     2017_act_reading  2017_act_science  2017_act_composite  \
# 25              20.8              20.5                20.4
# 40              19.1              18.9                18.7
#
#     2018_sat_participation  2018_sat_evidence_based_reading_and_writing  \
# 25                     4.0                                          633
# 40                    55.0                                          547
#
# ...

# %% [markdown]
# Missouri and South Carolina had 100% participation for the ACT in 2018 but did not have 100% participation for the ACT in 2019.
# Missouri had an 18% decrease in ACT participation between 2018 and 2019. South Carolina had a 22% decrease in ACT particiaption between 2018 and 2019.

# %%
# SAT 100% 2017 -> 2018
final[(final['2017_sat_participation'] == 100) & (final['2018_sat_participation'] < 100)]
# Out:
#                   state  2017_sat_participation  \
# 8  District of Columbia                   100.0
#
#    2017_sat_evidence_based_reading_and_writing  2017_sat_math  2017_sat_total  \
# 8                                          482            468             950
#
#    2017_act_participation  2017_act_english  2017_act_math  2017_act_reading  \
# 8                    32.0              24.4           23.5              24.9
#
#    2017_act_science  2017_act_composite  2018_sat_participation  \
# 8              23.5                24.2                    92.0
#
#    2018_sat_evidence_based_reading_and_writing  2018_sat_math  2018_sat_total  \
# 8                                          497            480             977
#
#    2018_act_participation  2018_act_composite  2019_act_participation  \
# 8                    32.0                23.6                    32.0
#
#    2019_act_composite  2019_sat_participation  \
# 8                23.5                    94.0
#
# ...

# %% [markdown]
# The District of Columbia had 100% participation for the SAT in 2018 but did not have 100% participation for the SAT in 2019.
# The District of Columbia had an 8% decrease in SAT participation between 2017 and 2018.

# %%
# SAT 100% 2018 -> 2019
final[(final['2018_sat_participation'] == 100) & (final['2019_sat_participation'] < 100)]
# Out:
# Empty DataFrame
# Columns: [state, 2017_sat_participation, 2017_sat_evidence_based_reading_and_writing, 2017_sat_math, 2017_sat_total, 2017_act_participation, 2017_act_english, 2017_act_math, 2017_act_reading, 2017_act_science, 2017_act_composite, 2018_sat_participation, 2018_sat_evidence_based_reading_and_writing, 2018_sat_math, 2018_sat_total, 2018_act_participation, 2018_act_composite, 2019_act_participation, 2019_act_composite, 2019_sat_participation, 2019_sat_evidence_based_reading_and_writing, 2019_sat_math, 2019_sat_total]
# Index: []

# %% [markdown]
# No states that had 100% participation rate for the 2018 SAT dropped below 100% participation rate for the 2019 SAT.

# %% [markdown]
# - Do any states show have >50% participation on *both* tests either year?

# %%
# The states show >50% participation for both test
final[(final['2017_act_participation'] > 50.0) & (final['2017_sat_participation'] > 50.0)]['state']
# Out:
# 9     Florida
# 10    Georgia
# 11     Hawaii
# Name: state, dtype: object

# %% [markdown]
# Florida, Georgia, and Hawaii show greater than 50% participation on both tests for 2017.

# %%
# The states show >50% participation for both test
final[(final['2018_act_participation'] > 50.0) & (final['2018_sat_participation'] > 50.0)]['state']
# Out:
# 9            Florida
# 10           Georgia
# 11            Hawaii
# 33    North Carolina
# 40    South Carolina
# Name: state, dtype: object

# %% [markdown]
# Florida, Georgia, Hawaii, North Carolina, and South Carolina show greater than 50% participation on both tests for 2018.

# %%
# The states show >50% participation for both test
final[(final['2019_act_participation'] > 50.0) & (final['2019_sat_participation'] > 50.0)]['state']
# Out:
# 9            Florida
# 11            Hawaii
# 33    North Carolina
# 40    South Carolina
# Name: state, dtype: object

# %% [markdown]
# Florida, Hawaii, North Carolina, and South Carolina show greater than 50% participation on both tests for 2019.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
import seaborn as sns

# %%
from string import ascii_letters

# %%
corr = final.corr()

# This makes the correlation plot in half
mask = np.triu(np.ones_like(corr, dtype=np.bool))
f, ax = plt.subplots(figsize=(14, 14))

# Changing the cmap
cmap = sns.diverging_palette(150, 10, as_cmap=True) # Looks like a watermelon now

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, annot=True, linewidths=.6, cbar_kws={"shrink": .5});

# Styling credit: https://seaborn.pydata.org/examples/many_pairwise_correlations.html

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
# column_list = final.columns

# %%
columns_list = ['2017_sat_participation', '2018_sat_participation', '2019_sat_participation', 
                '2017_sat_total','2018_sat_total', '2019_sat_total', 
                '2017_act_participation', '2018_act_participation','2019_act_participation', 
                '2017_act_composite', '2018_act_composite', '2019_act_composite']

# %%
xlabels = ['Participation Rate', 'Mean Totals', 'Participation Rate', 'Mean Composition']

# %%
# Haley Taft, James Pecore, Chris Johnson, Jenny James, and Lydia Kajeckas contributed to this code
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/3))     # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=3, figsize=(12,10)) # You'll want to specify your figsize
    fig.tight_layout(pad=2)
    ax = ax.ravel()                                   # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns):      # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column])       
        ax[i].set_title(list_of_titles[i])            # Set titles, labels, etc here for each subplot

# %%
subplot_histograms(final, columns_list, columns_list, xlabels)
# subplot_histograms(final, column_list[1:4], [], [])

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Haley Taft, James Pecore, Chris Johnson, Jenny James, and Lydia Kajeckas contributed to this code
def double_hist(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/3))     # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(12,3)) # You'll want to specify your figsize
    fig.tight_layout(pad=2)
    ax = ax.ravel()                                   # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns):      # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column])       
        ax[i].set_title(list_of_titles[i])

# %% [markdown]
# **- Participation rates for SAT & ACT:**

# %%
# This shows the comparison between SAT Participation rates and ACT Participation rates for 2017, 2018, 2019.

double_hist(
    final,
    ['2017_sat_participation','2017_act_participation'],
    ['2017 SAT Participation','2017 ACT Participation '],
    ['Mean Score','Mean Score'],
)
double_hist(
    final,
    ['2018_sat_participation','2018_act_participation'],
    ['2018 SAT Participation','2018 ACT Participation '],
    ['Mean Score','Mean Score'],
)
double_hist(
    final,
    ['2019_sat_participation','2019_act_participation'],
    ['2017 SAT Participation','2017 ACT Participation '],
    ['Mean Score','Mean Score'],
)

# %% [markdown]
# **- Math scores for SAT & ACT**

# %%
# Since the two 2017 datasets are the only datasets with both Math values this is the only comparison we can do.
double_hist(
    final,
    ['2017_sat_math','2017_act_math'],
    ['2017 SAT Math Distribution','2017 ACT Math Distribution'],
    ['Mean Score','Mean Score'],
)

# %% [markdown]
# **- Reading/verbal scores for SAT & ACT**

# %%
double_hist(
    final,
    ['2017_sat_evidence_based_reading_and_writing','2017_act_reading'],
    ['2017 SAT EBRW Distribution','2017 ACT Reading Distribution'],
    ['Mean Score','Mean Score'],
)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %% [markdown]
# **SAT vs. ACT math scores for 2017:**

# %%
plt.figure(figsize=(8,6))
plt.scatter(final['2017_sat_math'], final['2017_act_math'])
plt.xlabel('2017 SAT Math Score', fontsize=16)
plt.ylabel('2017 ACT Math Score', fontsize=16)
plt.title('2017 SAT vs ACT Math Scores', fontsize=16);

# %% [markdown]
# **SAT vs. ACT verbal/reading scores for 2017:**

# %%
# Code
plt.figure(figsize=(8,6))
plt.scatter(final['2017_sat_evidence_based_reading_and_writing'], final['2017_act_reading'])
plt.xlabel('2017 SAT EBRW Scores', fontsize=16)
plt.ylabel('2017 ACT Reading Scores', fontsize=16)
plt.title('2017 SAT vs ACT  Scores', fontsize=16);

# %% [markdown]
# **SAT vs. ACT total/composite scores for 2017:**

# %%
final.columns
# Out:
# Index(['state', '2017_sat_participation',
#        '2017_sat_evidence_based_reading_and_writing', '2017_sat_math',
#        '2017_sat_total', '2017_act_participation', '2017_act_english',
#        '2017_act_math', '2017_act_reading', '2017_act_science',
#        '2017_act_composite', '2018_sat_participation',
#        '2018_sat_evidence_based_reading_and_writing', '2018_sat_math',
#        '2018_sat_total', '2018_act_participation', '2018_act_composite',
#        '2019_act_participation', '2019_act_composite',
#        '2019_sat_participation', '2019_sat_evidence_based_reading_and_writing',
#        '2019_sat_math', '2019_sat_total'],
#       dtype='object')

# %%
# Code
plt.figure(figsize=(8,6))
plt.scatter(final['2017_sat_total'], final['2017_act_composite'])
plt.xlabel('2017 SAT Total Scores', fontsize=16)
plt.ylabel('2017 ACT Composite Scores', fontsize=16)
plt.title('2017 SAT vs ACT Total/Composite Scores', fontsize=16);

# %% [markdown]
# **Total scores for SAT 2017 vs. 2018:**

# %%
# Code
plt.figure(figsize=(8,6))
plt.scatter(final['2017_sat_total'], final['2018_sat_total'])
plt.xlabel('2017 SAT Total Scores', fontsize=16)
plt.ylabel('2018 SAT Total Scores', fontsize=16)
plt.title('2017 SAT Total Scores vs 2018 SAT Total Scores', fontsize=16);

# %% [markdown]
# **Composite scores for ACT 2017 vs. 2018:**

# %%
plt.figure(figsize=(8,6))
plt.scatter(final['2017_act_composite'], final['2018_act_composite'])
plt.xlabel('2017 ACT Composite', fontsize=16)
plt.ylabel('2018 ACT Composite', fontsize=16)
plt.title('2017 ACT Composite Scores vs 2018 ACT Compostie Scores', fontsize=16);

# %%
# Correlation between participation and mean scores
plt.figure(figsize=(8,5))
sns.scatterplot(final['2018_act_participation'],final['2018_act_composite'])
plt.xlabel('2018 ACT Participation Rate', fontsize=15)
plt.ylabel('2018 Average Composite Score', fontsize=15)
plt.title('2018 Inverse Relationship Between Participation and Mean Scores', fontsize=17);

# %%
# Correlation between participation and mean scores
plt.figure(figsize=(8,5))
sns.scatterplot(final['2018_sat_participation'],final['2018_sat_total'])
plt.xlabel('2018 SAT Participation Rate', fontsize=15)
plt.ylabel('2018 Mean SAT Total Score', fontsize=15)
plt.title(' 2018 Inverse Relationship Between Participation and Mean Scores', fontsize=17);

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Haley Taft, James Pecore, Chris Johnson, Jenny James, and Lydia Kajeckas contributed to this code
def box_plots(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/3))     # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=3, figsize=(12,3)) # You'll want to specify your figsize
    fig.tight_layout(pad=4)
    ax = ax.ravel()                                   # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns):      # Gives us an index value to get into all our lists
        sns.boxplot(dataframe[column], ax=ax[i]) 
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])

# %%
final.shape
# Out:
# (51, 23)

# %%
# SAT Participation
box_plots(
    final,
    ['2017_sat_participation','2018_sat_participation', '2019_sat_participation'],
    ['2017 SAT Participation','2018 SAT Participation', '2019 SAT Participation'],
    ['Participation Rate','Participation Rate', 'Participation Rate'],
)

# %%
# SAT EBRW
box_plots(
    final,
    ['2017_sat_evidence_based_reading_and_writing','2018_sat_evidence_based_reading_and_writing', '2019_sat_evidence_based_reading_and_writing'],
    ['2017 SAT EBRW','2018 SAT EBRW', '2019 SAT EBRW'],
    ['EBRW Rate','EBRW Rate', 'EBRW Rate'],
)

# %%
# SAT Math
box_plots(
    final,
    ['2017_sat_math','2018_sat_math', '2019_sat_math'],
    ['2017 SAT Math','2018 SAT Math', '2019 SAT Math'],
    ['Math Rate','Math Rate', 'Math Rate'],
)

# %%
# SAT Total
box_plots(
    final,
    ['2017_sat_total','2018_sat_total', '2019_sat_total'],
    ['2017 SAT Total','2018 SAT Total', '2019 SAT Total'],
    ['SAT Total Rate','SAT Total Rate', 'SAT Total Rate'],
)

# %%
# 2017 ACT because English, Math, Reading, and Science are not in the 2018 and 2019 datasets
box_plots(
    final,
    ['2017_act_participation','2017_act_english', '2017_act_math', '2017_act_reading', '2017_act_science', '2017_act_composite'],
    ['2017 ACT Participation','2017 ACT English', '2017 ACT Math', '2017 ACT Reading', '2017 ACT Science', '2017 ACT Composite'],
    ['Participation Rate','English Rate', 'Math Rate', 'Reading Rate', 'Science Rate', 'Composite Rate'],
)

# %%
# ACT Participation 
box_plots(
    final,
    ['2017_act_participation', '2018_act_participation', '2019_act_participation'],
    ['2017 ACT Participation','2018 ACT Participation', '2019 ACT Participation'],
    ['Participation Rate','Participation Rate', 'Participation Rate'],
)

# %%
# ACT Composite
box_plots(
    final,
    ['2017_act_composite', '2018_act_composite', '2019_act_composite'],
    ['2017 ACT Composite','2018 ACT Composite', '2019 ACT Composite'],
    ['Composite Rate','Composite Rate', 'Composite Rate'],
)

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %%
# Had to add two more columns avg sat participation rate, avg act participation rate
final.to_excel("final_1.xlsx")

# %% [markdown]
# # Tableau Maps
# - Average ACT participation rate for 2017, 2018, 2019
# https://public.tableau.com/profile/aidan.curle#!/vizhome/DivergentChloropethMapfortheAverageSATParticipationacross20172018and2019/Sheet1?publish=yes
#
# - Average SAT participation rate for 2017, 2018, 2019
# https://public.tableau.com/profile/aidan.curle#!/vizhome/DivergentChloropethMapfortheAverageSATParticipationRateacross20172018and2019/Sheet2?publish=yes

# %% [markdown]
# ## Outside Research!

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
# Florida's 2018 SAT Participation number is incorrect
final[(final['2018_sat_participation'] < 100.0) & (final['2019_sat_participation'] == 100.0)]
# Out:
#            state  2017_sat_participation  \
# 9        Florida                    83.0
# 13      Illinois                     9.0
# 39  Rhode Island                    71.0
#
#     2017_sat_evidence_based_reading_and_writing  2017_sat_math  \
# 9                                           520            497
# 13                                          559            556
# 39                                          539            524
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 9             1017                    73.0              19.0           19.4
# 13            1115                    93.0              21.0           21.2
# 39            1062                    21.0              24.0           23.3
#
#     2017_act_reading  2017_act_science  2017_act_composite  \
# 9               21.0              19.4                19.8
# 13              21.6              21.3                21.4
# ...

# %%
# Colorado, 
# Colorado had a 70 % decrease in act participation rates from 2017 to 2018
# And a 89% increase in SAT participation ratets from 2017 to 2018
# Colorao links:
# https://co.chalkbeat.org/2015/12/23/21092477/goodbye-act-hello-sat-a-significant-change-for-colorado-high-schoolers
# https://www.testive.com/colorado-sat-change-2017/

# %%
# Illinois SAT
# Illionis had a 90% increase in SAT participation rates from 2017 to 2018
# https://www.testive.com/illinois/

# %%
# In the dataframe Florida's participation rate in 2017 is 83% then in 2018 it is 56% then in 2019 it is 100%
# However in a report from collegeboard Florida in 2018 they had a 97% participation rate

# https://reports.collegeboard.org/pdf/2018-florida-sat-suite-assessments-annual-report.pdf

# %% [markdown]
# # Citations

# %% [markdown]
# - https://co.chalkbeat.org/2015/12/23/21092477/goodbye-act-hello-sat-a-significant-change-for-colorado-high-schoolers
# - https://www.testive.com/colorado-sat-change-2017/
# - https://reports.collegeboard.org/pdf/2018-florida-sat-suite-assessments-annual-report.pdf
# - https://www.testive.com/illinois/
# - https://seaborn.pydata.org/examples/many_pairwise_correlations.html
# - https://en.wikipedia.org/wiki/Red_states_and_blue_states
# - https://www.cnn.com/2014/03/05/living/sat-test-changes-schools/index.html
# - https://magoosh.com/hs/act/2017/states-that-require-the-act-or-sat/
# - https://magoosh.com/hs/act/2017/states-provide-act-free/
# - https://www.hanoverresearch.com/media/Best-Practices-to-Increase-SAT-Participation-1.pdf

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# **Conclusions and Recommendations:**
# For a guaranteed increase in participation rates on either test each state could implemenmt a state mandation that requires students to take the test. This is what colorado did and ended up having an 89% increase in SAT particpation from 2017 to 2018.
#
# However, having a state mandation is not possible across the board. Instead of requiring a state mandation there are a few things states could do to increase participation rates and increase mean total scores.
# - **First**, states could offer the SAT / ACT during school hours. This makes it so the students do not have to schedule it themselves and make accomadtions for going to the test. Which both could be big reasons why students do not take the tests.
# - **Second**, states should cover all parts of the exam fees. For students who get free lunches and free resources it is unjust to make them pay upwards of $50+ to take one of these exams and prepare for the exam. Not covering all the fees could also play a role in students not being able to actually take the test.
# - **Third**, increasing access to honors and AP courses. Students who take these classes are far more ready for the SAT and ACT tests. Increasing access to these test will aid in increasing participation while also increasing mean total scores.
# - **Fourth**, increasing access to PSAT/NMSQT. In my school we had to pay for this course and had to stay after school for a few hours a week which is not possible for some students. Increasing access to the PSAT/NMSQT will lead to a higher participation rate and a higher mean total score.

# %% [markdown]
# ## Bonus: Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:
