# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score

# %%
# Read in the train and test dataframes
train_df = pd.read_csv('./datasets/train.csv')
test_df = pd.read_csv('./datasets/test.csv')

# %%
train_df.head(1)
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 0          NaN        0       3    2010        WD      130500
#
# [1 rows x 81 columns]

# %%
test_df.head(1)
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
#
#   Alley Lot Shape Land Contour  ... 3Ssn Porch Screen Porch Pool Area Pool QC  \
# 0  Grvl       Reg          Lvl  ...          0            0         0     NaN
#
#   Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# 0   NaN          NaN        0       4     2006        WD
#
# [1 rows x 80 columns]

# %%
# 2051 rows of training data and 80 columns plus 'SalePrice'
train_df.shape
# Out:
# (2051, 81)

# %%
# 878 rows of testing data and only 80 columns
test_df.shape
# Out:
# (878, 80)

# %%
train_dummies = train_df[['Id','Neighborhood']]
train_new = pd.get_dummies(columns=['Neighborhood'], data=train_dummies, drop_first=True)
train_new.shape
# Out:
# (2051, 28)

# %%
test_dummies = test_df[['Id','Neighborhood']]
test_new = pd.get_dummies(columns=['Neighborhood'], data=test_dummies, drop_first=True)
test_new.shape
# Out:
# (878, 26)

# %%
# new_list = [
#     list(set(train_new.columns[1:]).difference(test_new.columns[1:]))
# ]
# new_list
# Out:
# [['Neighborhood_Landmrk', 'Neighborhood_GrnHill']]

# %%
for n in new_list:
    for xi in n:
        print(xi)
# Out:
# Neighborhood_Landmrk
# Neighborhood_GrnHill

# %%
[xi for xi in n for n in new_list]
# Out:
# ['Neighborhood_Landmrk', 'Neighborhood_GrnHill']

# %%
[xi for n in n for n in new_list]
# Out:
# ['Neighborhood_GrnHill', 'Neighborhood_GrnHill']

# %%
train_new.drop(columns=[[xi for n in n for n in new_list][0], [xi for n in n for n in new_list][1]])
# Out:
#         Id  Neighborhood_Blueste  Neighborhood_BrDale  Neighborhood_BrkSide  \
# 0      109                     0                    0                     0
# 1      544                     0                    0                     0
# 2      153                     0                    0                     0
# 3      318                     0                    0                     0
# 4      255                     0                    0                     0
# ...    ...                   ...                  ...                   ...
# 2046  1587                     0                    0                     0
# 2047   785                     0                    0                     0
# 2048   916                     0                    0                     0
# 2049   639                     0                    0                     0
# 2050    10                     0                    0                     0
#
#       Neighborhood_ClearCr  Neighborhood_CollgCr  Neighborhood_Crawfor  \
# 0                        0                     0                     0
# 1                        0                     0                     0
# 2                        0                     0                     0
# 3                        0                     0                     0
# 4                        0                     0                     0
# ...                    ...                   ...                   ...
# 2046                     0                     0                     0
# 2047                     0                     0                     0
# 2048                     0                     0                     1
# 2049                     0                     0                     0
# 2050                     0                     0                     0
#
#       Neighborhood_Edwards  Neighborhood_Gilbert  Neighborhood_Greens  ...  \
# 0                        0                     0                    0  ...
# 1                        0                     0                    0  ...
# 2                        0                     0                    0  ...
# 3                        0                     0                    0  ...
# 4                        0                     0                    0  ...
# ...                    ...                   ...                  ...  ...
# 2046                     0                     0                    0  ...
# 2047                     1                     0                    0  ...
# 2048                     0                     0                    0  ...
# 2049                     0                     0                    0  ...
# 2050                     0                     1                    0  ...
#
#       Neighborhood_NoRidge  Neighborhood_NridgHt  Neighborhood_OldTown  \
# 0                        0                     0                     0
# 1                        0                     0                     0
# 2                        0                     0                     0
# 3                        0                     0                     0
# 4                        0                     0                     0
# ...                    ...                   ...                   ...
# 2046                     0                     0                     0
# 2047                     0                     0                     0
# 2048                     0                     0                     0
# 2049                     0                     0                     0
# 2050                     0                     0                     0
#
#       Neighborhood_SWISU  Neighborhood_Sawyer  Neighborhood_SawyerW  \
# 0                      0                    1                     0
# 1                      0                    0                     1
# 2                      0                    0                     0
# 3                      0                    0                     0
# 4                      0                    0                     1
# ...                  ...                  ...                   ...
# 2046                   0                    0                     0
# 2047                   0                    0                     0
# 2048                   0                    0                     0
# 2049                   0                    0                     0
# 2050                   0                    0                     0
#
#       Neighborhood_Somerst  Neighborhood_StoneBr  Neighborhood_Timber  \
# 0                        0                     0                    0
# 1                        0                     0                    0
# 2                        0                     0                    0
# 3                        0                     0                    1
# 4                        0                     0                    0
# ...                    ...                   ...                  ...
# 2046                     0                     0                    1
# 2047                     0                     0                    0
# 2048                     0                     0                    0
# 2049                     0                     0                    0
# 2050                     0                     0                    0
#
#       Neighborhood_Veenker
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 2046                     0
# 2047                     0
# 2048                     0
# 2049                     0
# 2050                     0
#
# [2051 rows x 27 columns]

# %%
train_new.shape
# Out:
# (2051, 28)

# %%
# How to clean the continous feature I want
train_df['Lot Frontage']

# %%
# We need to clean the data :) This function should get me datasets of only the features I want
def clean_the_dfs(train, test):
    
    # Get dummies for the neighborhood column for TRAIN
    train_dummies = train[['Id','Neighborhood']]
    train_new = pd.get_dummies(columns=['Neighborhood'], data=train_dummies, drop_first=True)
    
    # Get dummies for the neighborhood column for TEST
    test_dummies = test[['Id','Neighborhood']]
    test_new = pd.get_dummies(columns=['Neighborhood'], data=test_dummies, drop_first=True)
    
    # This finds the columns that are not the same
    new_list = [list(set(train_new.columns[1:]).difference(test_new.columns[1:]))]
    
    # This drops the columns that are not the same in the train and test datasets
    train_new.drop(columns=[[xi for n in n for n in new_list][0], [xi for n in n for n in new_list][1]], inplace=True)
